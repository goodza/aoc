# %%
maze="""
                   A               
                   A               
  #################.#############  
  #.#...#...................#.#.#  
  #.#.#.###.###.###.#########.#.#  
  #.#.#.......#...#.....#.#.#...#  
  #.#########.###.#####.#.#.###.#  
  #.............#.#.....#.......#  
  ###.###########.###.#####.#.#.#  
  #.....#        A   C    #.#.#.#  
  #######        S   P    #####.#  
  #.#...#                 #......VT
  #.#.#.#                 #.#####  
  #...#.#               YN....#.#  
  #.###.#                 #####.#  
DI....#.#                 #.....#  
  #####.#                 #.###.#  
ZZ......#               QG....#..AS
  ###.###                 #######  
JO..#.#.#                 #.....#  
  #.#.#.#                 ###.#.#  
  #...#..DI             BU....#..LF
  #####.#                 #.#####  
YN......#               VT..#....QG
  #.###.#                 #.###.#  
  #.#...#                 #.....#  
  ###.###    J L     J    #.#.###  
  #.....#    O F     P    #.#...#  
  #.###.#####.#.#####.#####.###.#  
  #...#.#.#...#.....#.....#.#...#  
  #.#####.###.###.#.#.#########.#  
  #...#.#.....#...#.#.#.#.....#.#  
  #.###.#####.###.###.#.#.#######  
  #.#.........#...#.............#  
  #########.###.###.#############  
           B   J   C               
           U   P   P"""
            

l = [x.split() for x in maze.splitlines()]
print(l)
print(['#.....#', 'A', 'C', '#.#.#.#'][0])
# Out:
# [[], ['A'], ['A'], ['#################.#############'], ['#.#...#...................#.#.#'], ['#.#.#.###.###.###.#########.#.#'], ['#.#.#.......#...#.....#.#.#...#'], ['#.#########.###.#####.#.#.###.#'], ['#.............#.#.....#.......#'], ['###.###########.###.#####.#.#.#'], ['#.....#', 'A', 'C', '#.#.#.#'], ['#######', 'S', 'P', '#####.#'], ['#.#...#', '#......VT'], ['#.#.#.#', '#.#####'], ['#...#.#', 'YN....#.#'], ['#.###.#', '#####.#'], ['DI....#.#', '#.....#'], ['#####.#', '#.###.#'], ['ZZ......#', 'QG....#..AS'], ['###.###', '#######'], ['JO..#.#.#', '#.....#'], ['#.#.#.#', '###.#.#'], ['#...#..DI', 'BU....#..LF'], ['#####.#', '#.#####'], ['YN......#', 'VT..#....QG'], ['#.###.#', '#.###.#'], ['#.#...#', '#.....#'], ['###.###', 'J', 'L', 'J', '#.#.###'], ['#.....#', 'O', 'F', 'P', '#.#...#'], ['#.###.#####.#.#####.#####.###.#'], ['#...#.#.#...#.....#.....#.#...#'], ['#.#####.###.###.#.#.#########.#'], ['#...#.#.....#...#.#.#.#.....#.#'], ['#.###.#####.###.###.#.#.#######'], ['#
# ...

# %%
ll = [x for x in maze.splitlines()]
print(ll)
# Out:
# ['', '                   A               ', '                   A               ', '  #################.#############  ', '  #.#...#...................#.#.#  ', '  #.#.#.###.###.###.#########.#.#  ', '  #.#.#.......#...#.....#.#.#...#  ', '  #.#########.###.#####.#.#.###.#  ', '  #.............#.#.....#.......#  ', '  ###.###########.###.#####.#.#.#  ', '  #.....#        A   C    #.#.#.#  ', '  #######        S   P    #####.#  ', '  #.#...#                 #......VT', '  #.#.#.#                 #.#####  ', '  #...#.#               YN....#.#  ', '  #.###.#                 #####.#  ', 'DI....#.#                 #.....#  ', '  #####.#                 #.###.#  ', 'ZZ......#               QG....#..AS', '  ###.###                 #######  ', 'JO..#.#.#                 #.....#  ', '  #.#.#.#                 ###.#.#  ', '  #...#..DI             BU....#..LF', '  #####.#                 #.#####  ', 'YN......#               VT..#....QG', '  #.###.#                 #.###.#  ', '  #.#...#        
# ...
