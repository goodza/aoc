# %%
from collections import defaultdict

d = defaultdict(list)
for s in open('6.txt'):
    s1= s.split(')')[1].split('\n')[0]
    s0= s.split(')')[0]
    d[s1].append(s0)

# %%
print(d)
# Out:
# defaultdict(<class 'list'>, {'67Y': ['797'], '48L': ['W32'], 'N9K': ['J31'], 'NVL': ['QQ3'], 'JBY': ['MP6'], 'H27': ['8T3'], 'THF': ['DRK'], '7MD': ['BSN'], 'VRX': ['Z2G'], 'XDC': ['CVV'], 'SV6': ['WVW'], 'QMG': ['D3H'], 'NTH': ['9BM'], 'FQS': ['4T7'], 'D1Q': ['F58'], 'B7L': ['CR7'], 'T9Z': ['4W8'], '5JB': ['5SB'], 'YQD': ['DRJ'], 'X1Z': ['76X'], 'LNG': ['WC9'], 'W7J': ['52C'], 'KM7': ['9ZS'], 'C8R': ['3RW'], 'TJW': ['7RQ'], 'ZNQ': ['HVN'], 'CBT': ['SQK'], 'N76': ['GWC'], 'W44': ['KBQ'], 'RVQ': ['QD5'], 'N3K': ['SQF'], 'B2R': ['RZ1'], '34W': ['TB5'], 'CQD': ['J56'], 'HLX': ['34Y'], 'TD4': ['DTM'], 'SQV': ['2RF'], 'TFD': ['GJT'], '88B': ['CNK'], 'GD8': ['PJD'], 'FQN': ['4V8'], '6RS': ['HKH'], '2JT': ['7T4'], 'DMQ': ['DBM'], '137': ['59X'], 'B62': ['HK7'], 'K7Z': ['D34'], 'M74': ['RR2'], 'FC5': ['Q13'], '8XJ': ['1F1'], 'QZ9': ['K1L'], '4VT': ['T73'], '59X': ['Z7S'], 'GB6': ['1MQ'], '4BZ': ['BJT'], 'DT2': ['WW8'], '6SH': ['JYL'], 'WC9': ['R2K'], '4ZD': ['21H'], 'QWZ': ['Z7Z'], 'LRZ': ['
# ...

# %%
ddeep = dict()

def deep(e):
    n = 0
    if d[e] != []:
        n+=1
        n+=deep(d[e][0])
    return n

c = 0
for i in d:
    c+=deep(i)
c
# Out:
# 315757
